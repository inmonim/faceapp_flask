# %% [markdown]
# <h3> 모듈 임포트

# %%
# -*- coding: utf8 -*-

import numpy as np
import cv2
import os
from torchvision import transforms

# %% [markdown]
# <h2>함수 생성

# %%
#얼굴 잡아주기

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

#리사이징

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

#함수 생성

count = 0
def get_prediction(image_bytes, cnt):
    ff = np.fromfile(image_bytes, np.uint8)
    img = cv2.imdecode(ff, cv2.IMREAD_UNCHANGED)
    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    gray = cv2.cvtColor(rgb, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    if(len(faces) != 0):
        for (x,y,w,h) in faces:
            cropped = img[y - int(h / 4):y + h + int(h / 4), x - int(w / 4):x + w + int(w / 4)]
            if cropped.size != 0:
                print(cropped)
                cv2.imwrite('./crop/image_'+str(cnt)+'.jpg', cropped)

# %% [markdown]
# <h2> 네임 리스트 로드

# %%
f = open('name.txt', 'r', encoding='utf-8')
name = f.readline()
name = name.replace('\'', '')
name = name.replace(' ', '')
class_names = name.split(',')
f.close()
# Out:
# ['강동원',
#  '강민경',
#  '강세련',
#  '강형욱',
#  '강호동',
#  '고소영',
#  '고준희',
#  '공유',
#  '곽도원',
#  '구혜선',
#  '권나라',
#  '권상우',
#  '권정열',
#  '기리보이',
#  '김가영',
#  '김경호',
#  '김고은',
#  '김남길',
#  '김다미',
#  '김민주',
#  '김민희',
#  '김병만',
#  '김새론',
#  '김성균',
#  '김세연',
#  '김소현',
#  '김수현',
#  '김용만',
#  '김우빈',
#  '김유정',
#  '김윤석',
#  '김정현',
#  '김준호',
#  '김지민',
#  '김지원',
#  '김태리',
#  '김태원',
#  '김태희',
#  '김향기',
#  '김현수',
#  '김혜수',
#  '김희선',
#  '김희철',
#  '남규리',
#  '남주혁',
#  '노윤서',
#  '노지선',
#  '더콰이엇',
#  '데프콘',
#  '디노',
#  '로이킴',
#  '류승범',
#  '류준열',
#  '문근영',
#  '문세윤',
#  '문채원',
#  '미연',
#  '민경훈',
#  '민효린',
#  '박규영',
#  '박명수',
#  '박보검',
#  '박보영',
#  '박서준',
#  '박소담',
#  '박수진',
#  '박신혜',
#  '박연경',
#  '박완규',
#  '박중훈',
#  '박지윤',
#  '박해수',
#  '박형식',
#  '배정남',
#  '백예린',
#  '백종원',
#  '버논',
#  '범규',
#  '뷔',
#  '빈지노',
#  '서강준',
#  '서지혜',
#  '설인아',
#  '성시경',
#  '소지섭',
#  '손석구',
#  '손예진',
#  '손태영',
#  '손호준',
#  '송강',
#  '송강호',
#  '송승헌',
#  '송중기',
#  '송하영',
#  '송혜교',
#  '수지',
#  '슈가',
#  '스윙스',
#  '신동엽',
#  '신민아',
# ...

# %% [markdown]
# <h2>크롭 이미지 생성

# %%
# for i in name:
#     tx = './static/images/'+i+'.jpg'
#     get_prediction(tx, count)
#     count += 1

# %% [markdown]
# <h2> 리네임

# %%
for k,v in enumerate(class_names):
    old_name = os.path.join("C:/Users/user/Desktop/project_3-2/crop", "image_"+str(k)+".jpg")
    new_name = os.path.join("C:/Users/user/Desktop/project_3-2/crop", v+".jpg")
    os.rename(old_name, new_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8808/522843903.py in <module>
#       1 for k,v in enumerate(class_names):
#       2     old_name = os.path.join("C:/Users/user/Desktop/project_3-2/crop", "image_"+str(k)+".jpg")
# ----> 3     new_name = os.path.join("C:/Users/user/Desktop/project_3-2/crop", name_dict[v]+".jpg")
#       4     os.rename(old_name, new_name)
#
# KeyError: '강동원'

# %%
# Out:
# {0: '공', 1: '유'}
